# %%
import opal
from opal.opal import load_dataset, filetype
from opal.visualization.styles import load_style
load_style('jupyter')
# Out:
# C:\Users\asihn\Anaconda3\envs\fieldmaps\lib\site-packages\opal-1.0.0-py3.7.egg\opal\visualization\styles\default.py:186: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   mpl.rcParams['mathtext.fallback_to_cm'] = True
# C:\Users\asihn\Anaconda3\envs\fieldmaps\lib\site-packages\opal-1.0.0-py3.7.egg\opal\visualization\styles\default.py:186: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   mpl.rcParams['mathtext.fallback_to_cm'] = True
# C:\Users\asihn\Anaconda3\envs\fieldmaps\lib\site-packages\opal-1.0.0-py3.7.egg\opal\visualization\styles\default.py:186: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %%
ds = load_dataset('C:/Users/asihn/Downloads', fname='sc_inj_2d.stat')
ds1 = load_dataset('C:/Users/asihn/Downloads', fname='sc_inj_3d_final.stat')

# %%
print(ds)

# %%
plt = ds.plot_profile1D('s', 'Ez_ref', xsci=True)
plt = ds1.plot_profile1D('s', 'Ez_ref', xsci=True)
plt.xlim(0, 1)
plt.ylim(-20,3)
plt.legend(['2D', '3D'])
plt.show()

# %%
plt = ds.plot_profile1D('s', 'Bz_ref', xsci=True)
plt = ds1.plot_profile1D('s', 'Bz_ref', xsci=True)
plt.xlim(0, 1)
plt.legend(['2D', '3D'])
plt.show()

# %%
plt = ds1.plot_profile1D('s', 'Ex_ref', xsci=True)
plt = ds1.plot_profile1D('s', 'Ey_ref', xsci=True)
plt.xlim(0, 1)
plt.ylim(-0.0003, 0.0003)
plt.ylabel('E-field component of ref. particle [MV/m]')
plt.legend(['Ex', 'Ey'])
plt.show()

# %%
plt = ds.plot_profile1D('s', 'Bx_ref', xsci=True)
plt = ds1.plot_profile1D('s', 'By_ref', xsci=True)
plt.xlim(0, 1)
plt.ylabel('B-field component of ref. particle [T]')
plt.legend(['Bx', 'By', 'Bz'])
plt.show()

# %%
plt = ds.plot_profile1D('s', 'emit_x', xsci=True)
plt = ds1.plot_profile1D('s', 'emit_x', xsci=True)

#plt.xlim(-1e-7, 5e-6)
#plt.ylim(0,0.0000006)
plt.xlim(-1e-7,3)
plt.ylim(0,10e-6)
plt.legend(['2D', '3D'])
plt.show()

# %%
#plt = ds.plot_profile1D('s', 'rms_s', xsci=True)
plt = ds1.plot_profile1D('s', 'rms_s', xsci=True)
#plt.legend(['2D', '3D'])
plt.show()
